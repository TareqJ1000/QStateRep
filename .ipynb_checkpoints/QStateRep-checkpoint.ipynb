# %% [markdown]
# ## Question 3: Restricted Boltzmann Machine (20 points)

# %% [markdown]
# In this exercise you will implement and train a restricted Boltzmann machine (RBM) to write the number "5". The RBM will be trained on the MNIST dataset as used in question 2. To implement and train the RBM, follow these steps:
# 1. Implement the Gibbs sampling process and contrastive divergence. For this, first define two functions, one that creates a new sample of visible neurons given a hidden neuron configuration, and one that creates a new sample of hidden neurons given a visible neuron configuration. Use the function 'np.random.rand(shape)' to generate an array of shape 'shape' with random numbers between 0 and 1. Then define a function that implements the contrastive divergence update rule for the weight and bias parameters given a set of training data examples.
# 2. Having defined these functions, the RBM can be trained. You are provided code that imports the MNIST training data and brings it into a desired shape. We decrease the input dimension by considering images of 14x14 pixels, where we only take every second column and row into account. We then randomly choose 100 examples that we train the RBM on. Finally, the MNIST data set encodes grayscale images in numbers between 0 and 1, but we need a binary input for the RBM. We thus transform the input data into a binary representation by setting all values <0.5 to zero and all values >=0.5 to one. All these data processing steps are provided in the cell below (avoid any changes to the provided code), so that you can directly use the array 'training_batch' as input to the RBM. This array is of shape 100x196 and contains 100 input images in sequences of 196 pixels.</br>
# Initialize an RBM with 14x14=196 visible neurons and 50 hidden neurons with connecting weights and visible and hidden bias parameters. For all those weight and bias parameters choose random initial values between -0.05 and 0.05. Apply 50 training epochs of contrastive divergence to update the network parameters.
# 3. Having trained the RBM, keep the weight and bias parameters fixed and draw 1,000 visible neuron configurations using the Gibbs sampling procedure. Start with a randomly initialized vector for the visible neurons. Store all 1,000 sampled visible neuron configurations in a single array of shape 1,000x196.
# 4. Use 'plt.imshow(v)' to plot the visible neuron configurations in the following way. In order to see the output, reshape each visible neuron configuration into a 14x14 array to get back to the initial input image representation. Create three plots, one showing the first sampled visible neuron configuration, one showing the last sampled visible neuron configuration, and one showing the average of the last 900 samples of visible neurons. Which of these provides the most accurate digit drawing? Why is this the case?

# %%
#############################################################################################################################################
##################### This code is provided to import the training data and bring it into the desired shape. ################################
#############################################################################################################################################

# Import all packages
import numpy as np
import matplotlib.pyplot as plt

import torch

from torch.utils.data import DataLoader
from torchvision import datasets

from torchvision.transforms import ToTensor

# Download training data from open datasets
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

### Collect training data ###
# Turn training data and labels into numpy arrays as we won't use PyTorch in this part
X_data = training_data.data.numpy()
y_data = training_data.targets.numpy()

# We are only interested in training examples that display a 5
training_batch = X_data[y_data == 5]

# We only take every second entry to reduce the dimension of the input data to 14x14 pixels
# And we randomly select 100 training examples
index = np.random.randint(0, np.shape(training_batch)[0], (100))
training_batch = training_batch[index,::2,::2]

# We flatten each input example into a one-dimensional array
training_batch = training_batch.reshape(np.shape(training_batch)[0], -1)

# Finally, we turn the input data into binary values by setting all values <0.5 to zero and all values >=0.5 to 1
# We achieve this by checking for every element whether the statement >= 0.5 is true (value 1) or false (value 0).
training_batch = (training_batch >= 0.5).astype(np.int_)

#############################################################################################################################################
#############################################################################################################################################

# %% [markdown]
# 1. Implement the Gibbs sampling process and contrastive divergence. For this, first define two functions, one that creates a new sample of visible neurons given a hidden neuron configuration, and one that creates a new sample of hidden neurons given a visible neuron configuration. Use the function 'np.random.rand(shape)' to generate an array of shape 'shape' with random numbers between 0 and 1. Then define a function that implements the contrastive divergence update rule for the weight and bias parameters given a set of training data examples.
#
# Initialize an RBM with 14x14=196 visible neurons and 50 hidden neurons with connecting weights and visible and hidden bias parameters. For all those weight and bias parameters choose random initial values between -0.05 and 0.05. Apply 50 training epochs of contrastive divergence to update the network parameters.

# %%
# Let's define the sigmoid function. The Gibbs sampler thingy is predictated on computing conditional probabilities. 

class ResBoltMan():
    def __init__(self, num_visi, num_hid): 
        
        self.num_visi = num_visi
        self.num_hid = num_hid
        self.hid = np.random.randint(0, 2, size=num_hid)
        
        #self.visi = np.random.randint(0, 2, size=num_visi)
        self.weights = np.random.uniform(-0.05,0.05, size=(num_visi, num_hid)) 
        self.bias_visi = np.random.uniform(0, 0.05, size=num_visi)
        self.bias_hid = np.random.uniform(0, 0.05, size=num_hid)
        
    def sigmoid(self, z):
        return 1/(1 + np.exp(-z))
    
    def prob_function(self, visi, hid): # This computes p(v,h). We assume that v and h are seperate neuron configurations  
        total_prob = 0 
        for ii in range(num_visi):
            for jj in range(num_hid):
                first_term= visi[ii]@self.weights[ii, jj]@hid[jj]
                second_term = visi[ii]@self.bias_visi[ii]
                third_term = hid[jj]@self.bias_hid[jj]
        
        return np.exp(first_term + second_term + third_term)
    
    def unnorm_prob_function(self, visi, hid_list): # Given a batch of visible neuron configuartions, this computes sum_(p(v,h))
        total_prob = 0
        for hid in hid_list: 
            total_prob += self.prob_function(visi, hid)
            
        return total_prob
    
    def grad_update(self, visi_list_0, hid_list_0, visi_list_1, hid_list_1, lr): # This computes the expectation values of quantities necessary to update the parameters
        
        for i in range(num_visi):
            for j in range(num_hid):
                self.weights[i,j] += lr*np.mean(visi_list_0[:, i]*hid_list_0[:, j] - visi_list_1[:, i]*hid_list_1[:, j])       
                                                
        for i in range(num_visi):
            self.bias_visi[i] += lr*np.mean(visi_list_0[:, i] - visi_list_1[:,i])
            
        for j in range(num_hid):
            self.bias_hid[j] += lr*np.mean(hid_list_0[:, j] - hid_list_1[:, j])
            
        
    def v_given_h(self, i):
        # This function computes the conditional probability that the visible neuron is equal to 1
        # b_v -> visible neuron bias
        # W -> weight vector of RBM 
        # h -> hidden neuron vector 
        # i -> i_th visible neuron
    
        sum_over_hidden = np.sum(np.array([self.weights[i,j]*self.hid[j] for j in range(self.num_hid)]))
        
        return self.sigmoid(self.bias_visi[i] + sum_over_hidden)
    
    def h_given_v(self, visi, j):
        # This function computes the conditional probability that the hidden neuron is equal to 1
        # b_h -> hidden neuron bias
        # W -> weight vector of RBM 
        # v -> input visible neuron vector 
        # j -> j_th visible neuron
        
        sum_over_visible = np.sum(np.array([self.weights[i,j]*visi[i] for i in range(self.num_visi)]))
        return self.sigmoid(self.bias_hid[j] + sum_over_visible) 
    
    def sample_new_v(self):
        # Samples a new visible vector given hidden neuron configuration 
        # v - visible neuron vector
        # h - hidden neuron vector 
        # W - weight vector
        # b_v - visible bias vector 
    
        # Let's instantiate a copy of the visible neuron vector 
        visi_neo = np.zeros(self.num_visi)
    
        # Let's create a series of uniformly distributed random values between 0 and 1 
        rand_visi = np.random.rand(self.num_visi)
    
        # The conditional probability defines the threshold. If it's less than or equal to this threshold, set the corresponding visible vector to 1. 
        
        for ii in range(self.num_visi):
            if (rand_visi[ii] < self.v_given_h(ii)):
                visi_neo[ii] = 1
            else:
                visi_neo[ii] = 0 

        return visi_neo 
    
        #self.visi = visi_neo
    
    def sample_new_h(self, visi): 
        
        # Samples a new visible vector given hidden neuron configuration 
        # v - visible neuron vector
        # h - hidden neuron vector 
        # W - weight vector
        # b_v - visible bias vector 
    
        # Let's instantiate a copy of the visible neuron vector 
        hid_neo = np.zeros(self.num_hid)
    
        # Let's create a series of uniformly distributed random values between 0 and 1 
        rand_visi = np.random.rand(self.num_hid)
    
        # The conditional probability defines the threshold. If it's less than or equal to this threshold, set the corresponding visible vector to 1. 
        for jj in range(self.num_hid):
            if (rand_visi[jj] < self.h_given_v(visi, jj)):
                hid_neo[jj] = 1
            else:
                hid_neo[jj] = 0 
        
        self.hid = hid_neo
        
        
# Initialize random weight, bias vectors + visible, hidden neuron configuration

num_visi = 14*14 # dimensionality of MNIST images
num_hid = 50 

rbm_mnist = ResBoltMan(num_visi, num_hid)

# %% [markdown]
# Define a function which updates the weights and bias vectors based on CD rules

# %%
import time

def contrastive_div(train_dataset, rbm, epochs=50, lr=0.01, batch_size = 5, verbose=0): 
    num_of_batches = int(len(train_dataset)/batch_size)
    start_time = time.time()
    # Pick visible configurations from the dataset batchwise
    for ii in range(epochs): 
        print("**********")
        print(f"Epoch {ii}")
        # We need to iterate over the training set. For now, we iterate over datapoints, not batches
        for b in range(num_of_batches): 
            
            print("****")
            print(f"Batch {b}")
            
            v_batch = train_dataset[batch_size*b:batch_size*(b+1)] # the visible neuron configuration from the dataset
            h_stuff_one = [] # the hidden neuron configuration after having done one Gibbs sampling step 
            h_stuff_two = [] # after two Gibbs sampling step
            v_stuff = [] # Sampling the visible neuron config after one Gibbs sampling step. 
            
            for v in v_batch:
                # Get h by performing a Gibbs Sampling step 
                rbm.sample_new_h(v)
                # Store the hidden vector for later 
                h_stuff_one.append(rbm.hid)
                # Get v_temp by performing a Gibbs Sampling step 
                v_temp = rbm.sample_new_v()
                v_stuff.append(v_temp)
                # Using v_temp, sample a new h vector by performing a Gibbs Sampling step 
                rbm.sample_new_h(v_temp)
                h_stuff_two.append(rbm.hid)
            
            # The next step is to compute the updates on the weight parameters
            # grad_update(self, visi_list_0, hid_list_0, visi_list_1, hid_list_1, i,j, lr, expect='weight')
        
            rbm.grad_update(v_batch, np.array(h_stuff_one), np.array(v_stuff), np.array(h_stuff_two), lr)
            
            if(verbose==1):
                print(f"Weights: {rbm.weights} ")
                print(f"Visible Bias: {rbm.bias_visi}")
                print(f"Hidden Bias: {rbm.bias_hid}")

        
contrastive_div(training_batch, rbm_mnist)
# Out:
# **********
# Epoch 0
# ****
# Batch 0
# ****
# Batch 1
# ****
# Batch 2
# ****
# Batch 3
# ****
# Batch 4
# ****
# Batch 5
# ****
# Batch 6
# ****
# Batch 7
# ****
# Batch 8
# ****
# Batch 9
# ****
# Batch 10
# ****
# Batch 11
# ****
# Batch 12
# ****
# Batch 13
# ****
# Batch 14
# ****
# Batch 15
# ****
# Batch 16
# ****
# Batch 17
# ****
# Batch 18
# ****
# Batch 19
# **********
# Epoch 1
# ****
# Batch 0
# ****
# Batch 1
# ****
# Batch 2
# ****
# Batch 3
# ****
# Batch 4
# ****
# Batch 5
# ****
# Batch 6
# ****
# Batch 7
# ****
# Batch 8
# ****
# Batch 9
# ****
# Batch 10
# ****
# Batch 11
# ****
# Batch 12
# ****
# Batch 13
# ****
# Batch 14
# ****
# Batch 15
# ****
# Batch 16
# ****
# Batch 17
# ****
# Batch 18
# ****
# Batch 19
# **********
# Epoch 2
# ****
# Batch 0
# ****
# Batch 1
# ****
# Batch 2
# ****
# Batch 3
# ****
# Batch 4
# ****
# Batch 5
# ****
# Batch 6
# ****
# Batch 7
# ****
# Batch 8
# ****
# Batch 9
# ****
# Batch 10
# ****
# Batch 11
# ****
# Batch 12
# ****
# ...

# %% [markdown]
# 3. Having trained the RBM, keep the weight and bias parameters fixed and draw 1,000 visible neuron configurations using the Gibbs sampling procedure. Start with a randomly initialized vector for the visible neurons. Store all 1,000 sampled visible neuron configurations in a single array of shape 1,000x196.

# %%
# Let's create a new array that will hold our visible neuron configurations 

visi_neuron_configs = np.zeros(shape=(1000, num_visi))

# Perform Gibbs sampling

for ii in range(1000):
    
    print(f"Visible Neuron Configuration {ii}")
    
    # Sample new v and store it in our array
    temp = rbm_mnist.sample_new_v()
    visi_neuron_configs[ii, :] = rbm_mnist.sample_new_v()
    
    # Sample new h
    rbm_mnist.sample_new_h(temp)
# Out:
# Visible Neuron Configuration 0
# Visible Neuron Configuration 1
# Visible Neuron Configuration 2
# Visible Neuron Configuration 3
# Visible Neuron Configuration 4
# Visible Neuron Configuration 5
# Visible Neuron Configuration 6
# Visible Neuron Configuration 7
# Visible Neuron Configuration 8
# Visible Neuron Configuration 9
# Visible Neuron Configuration 10
# Visible Neuron Configuration 11
# Visible Neuron Configuration 12
# Visible Neuron Configuration 13
# Visible Neuron Configuration 14
# Visible Neuron Configuration 15
# Visible Neuron Configuration 16
# Visible Neuron Configuration 17
# Visible Neuron Configuration 18
# Visible Neuron Configuration 19
# Visible Neuron Configuration 20
# Visible Neuron Configuration 21
# Visible Neuron Configuration 22
# Visible Neuron Configuration 23
# Visible Neuron Configuration 24
# Visible Neuron Configuration 25
# Visible Neuron Configuration 26
# Visible Neuron Configuration 27
# Visible Neuron Configuration 28
# ...

# %% [markdown]
# 4. Use 'plt.imshow(v)' to plot the visible neuron configurations in the following way. In order to see the output, reshape each visible neuron configuration into a 14x14 array to get back to the initial input image representation. Create three plots, one showing the first sampled visible neuron configuration, one showing the last sampled visible neuron configuration, and one showing the average of the last 900 samples of visible neurons. Which of these provides the most accurate digit drawing? Why is this the case?

# %%
# Reshape the first, last, and the average of configurations 100 - 1000
first_visi_config = np.reshape(visi_neuron_configs[0], newshape=(14,14))
last_visi_config = np.reshape(visi_neuron_configs[-1], newshape=(14,14))
mean_visi_config = np.reshape(np.mean(visi_neuron_configs[100:1000], axis=0), newshape=(14,14))

# Plot the resulting configurations 
plt.imshow(first_visi_config)

# %%
# Plot the resulting configurations 
plt.imshow(last_visi_config)

# %%
# Plot the resulting configs

plt.imshow(mean_visi_config)

# %% [markdown]
# The averaged out configuration outputs the most accurate digit of the bunch. The stochasticity of the other configurations is "averaged away", leaving the core pattern underlying the visible configurations
